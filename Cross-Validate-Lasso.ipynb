# %%
import numpy as np
from sklearn.covariance import GraphicalLassoCV
import matplotlib.pyplot as plt

data = np.loadtxt('enzyme.txt',skiprows=1)

cov = GraphicalLassoCV(cv=5).fit(data)
prec_ = cov.precision_
print(prec_)

plt.figure(figsize=(4, 3))
plt.axes([0.2, 0.15, 0.75, 0.7])
plt.plot(cov.cv_results_["alphas"], cov.cv_results_["mean_score"], "o-")
plt.axvline(cov.alpha_, color=".5")
plt.ylabel("Cross-validation score")
plt.xlabel("alpha")

precs = "GraphicalLasso", prec_
vmax = 0.9 * prec_.max()
plt.imshow(np.ma.masked_equal(prec_, 0),interpolation="nearest",vmin=-vmax,vmax=vmax,cmap=plt.cm.RdBu_r)
plt.xticks(())
plt.yticks(())
plt.title("%s precision" % name)
if hasattr(ax, "set_facecolor"):
    ax.set_facecolor(".7")
else:
        ax.set_axis_bgcolor(".7")

plt.show()
# Out:
# [[ 0.79276394  0.          0.19357456 -0.01473578  0.10164991]
#  [ 0.          0.38124003 -0.0134124   0.          0.        ]
#  [ 0.19357456 -0.0134124   0.24014767  0.22173181 -0.        ]
#  [-0.01473578  0.          0.22173181  0.39900959  0.0983491 ]
#  [ 0.10164991  0.         -0.          0.0983491   0.82527457]]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-61de4e81b49b> in <module>
#      91 plt.figure(figsize=(4, 3))
#      92 plt.axes([0.2, 0.15, 0.75, 0.7])
# ---> 93 plt.plot(model.cv_results_["alphas"], model.cv_results_["mean_score"], "o-")
#      94 plt.axvline(model.alpha_, color=".5")
#      95 plt.title("Model selection")
#
# AttributeError: 'GraphicalLassoCV' object has no attribute 'cv_results_'
